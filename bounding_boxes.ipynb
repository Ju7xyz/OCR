# %%
import pytesseract
import cv2

# %%
image = cv2.imread("data/page_01.JPG")
base_image = image.copy()

# %%
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# %%
cv2.imwrite("temp/index_gray.png", gray)
# Out:
# True

# %%
blur = cv2.GaussianBlur(gray, (7,7), 0)

# %%
cv2.imwrite("temp/index_blur.png", blur)
# Out:
# True

# %%
thresh = cv2.threshold(blur, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)[1]

# %%
cv2.imwrite("temp/index_tresh.png", thresh)
# Out:
# True

# %%
kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 13))

# %%
cv2.imwrite("temp/index_kernel.png", kernel)
# Out:
# True

# %%
dilate = cv2.dilate(thresh, kernel, iterations=1)

# %%
cv2.imwrite("temp/index_dilate.png", dilate)
# Out:
# True

# %%
cnts = cv2.findContours(dilate, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
cnts = cnts[0] if len(cnts) == 2 else cnts[1]

# %%
cnts = sorted(cnts, key=lambda x: cv2.boundingRect(x)[0])

# %%
results = []
for c in cnts:
    x, y, w, h = cv2.boundingRect(c)
    if h > 200 and w > 20:
        roi = image[y:y+h, x:x+h]
        cv2.rectangle(image, (x, y), (x+w, y+h), (36, 255, 12), 2)
        ocr_result = pytesseract.image_to_string(roi)
        ocr_result = ocr_result.split("\n")
        for item in ocr_result:
            results.append(item)
cv2.imwrite("temp/index_bbox.png", image)
# Out:
# True

# %%
print(results)
# Out:
# ['   ', '', '  ', '', ' ', '', 'd', '', ' ', '', ' ', '', '4.13 Rules on Graduation', '', 'f Northern Philippine', 'Student Manunl', 'Veriton 2', '', 'subjects may still be allowed to continue depending on the merits of', 'their case.', '', 'Students who area issued Certificate of Honorable Dismissal/Permit', 'to Transfer can be re-admitted to the university provided they have', 'not been disqualified from the University.', '', 'In the absence of CHED Memorandum Order (CMO) on the', 'retention policies per program, the general retention policies shall be', 'adopted.', '', 'Academic Unit Retention Policies shall be provided for in the', 'respective bulletin of information of each college.', '', 'Candidates for graduation must file their application for graduation', '', 'within the term preceding the final term in the University.', '', 'The adviser endorses the application to the Dean with the following', '', 'attachments:', '', 'b.1. Student’s evaluation sheets,', '', 'b.2. Eight (8) bound copies of the approved thesis/dissertation, or', 'its equivalent (if applicable), and', '', 'b.3. Photocopy of approval sheet of said thesis/dissertation (if', 'applicable) and four (4) CD copies of the same.', '', 'Candidates for graduation in the Graduate Programs must present', '', 'their thesis/dissertation in a conference as a requirement for', '', 'graduation in addition to the submission of bound thesis/dissertation', '', '(BOR Resolution No.88-E, s.2015).', '', 'The Deans endorse the application for graduation with their', '', 'recommendation to the Office of the University Registrar.', '', 'The University Registrar appraises the academic records of the', '', 'candidates to determine whether they have deficiencies or have', '', 'fulfilled all the requirements for graduation. Names of candidates', '', 'found to have deficiencies shall be deleted from the list of candidates', '', 'for graduation. Four (4) weeks before the end of the final term, the', '', 'University Registrar shall publish a complete list of duly qualified', '', 'candidates for graduation for the term, which shall be returned to the', '', 'Dean. The Dean submits the list to the Office of Vice President for', '', 'Academic Affairs for endorsement to the Academic Council.', '', 'Conferment of honors to undergraduate students', '', 'f.1. Students who complete a degree program with the following', 'range of weighted average, shall graduate with academic honors', '', 'as follows:', 'Summa Cum Laude 1.000 to 1.250', 'Magna Cum Laude 1.251 to 1.500', 'Cum Laude 1.501 to 1.750', '', 'f.2. For certificate and special programs, the English equivalent of', 'the academic awards shall be used:', '', 'With Highest Honors 1.000 to 1.250', 'With High Honors 1.251 to 1.500', 'With Honors 1.501 to 1.750', '', 'f.3. Candidates for graduation with honors must have completed at', 'least seventy-five percent (75%) of the total number of academic', 'units or hours required for graduation and must have continuous', '', '13', '', ' ', '', ' ', '      ', '    ', '     ', '   ', '   ', '   ', '     ', '   ', '  ', '      ', '   ', '   ', '    ', '     ', '    ', '    ', '    ', '   ', '   ', '   ', '   ', '   ', '   ', '   ', '   ', '    ', '\x0c', '\x0c']

# %%
for item in results:
    item = item.strip()
    item = item.split(" ")[0]
    if len(item) > 0:
        if item[0].isupper():
            print(item)
# Out:
# Student
# Veriton
# Students
# In
# Academic
# Candidates
# The
# Candidates
# The
# The
# University
# Dean.
# Academic
# Conferment
# Summa
# Magna
# Cum
# With
# With
# With
