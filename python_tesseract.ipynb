# %%
import pytesseract
from PIL import Image
import gradio as gr

# %%
img_file = "data/page_01.jpg"
gray = "temp/gray.jpg"

# %%
img = Image.open(gray)

# %%
ocr_result = pytesseract.image_to_string(img)

# %%
#print(ocr_result)
